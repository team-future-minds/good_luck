# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install numpy matplotlib pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../artifacts/Restaurant_reviews.csv')

# %%
data
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review Rating  \
# 0     The ambience was good, food was quite good . h...      5
# 1     Ambience is too good for a pleasant evening. S...      5
# 2     A must try.. great food great ambience. Thnx f...      5
# 3     Soumen das and Arun was a great guy. Only beca...      5
# 4     Food is good.we ordered Kodi drumsticks and ba...      5
# ...

# %%
data.shape
# Out:
# (10000, 8)

# %%
data = data('review')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data = data('review')
#
# TypeError: 'DataFrame' object is not callable

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas numpy scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Anuththara\Desktop\fyp\good_luck\notebooks

# %%
data
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review Rating  \
# 0     The ambience was good, food was quite good . h...      5
# 1     Ambience is too good for a pleasant evening. S...      5
# 2     A must try.. great food great ambience. Thnx f...      5
# 3     Soumen das and Arun was a great guy. Only beca...      5
# 4     Food is good.we ordered Kodi drumsticks and ba...      5
# ...

# %% [markdown]
# Cleaning & Preparing Data

# %%
pip install nltk textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(36)

# %%
data.isnull().sum()
# Out:
# Restaurant       0
# Reviewer        38
# Review          45
# Rating          38
# Metadata        38
# Time            38
# Pictures         0
# 7514          9999
# dtype: int64

# %%
data["Review"].head(5)
# Out:
# 0    The ambience was good, food was quite good . h...
# 1    Ambience is too good for a pleasant evening. S...
# 2    A must try.. great food great ambience. Thnx f...
# 3    Soumen das and Arun was a great guy. Only beca...
# 4    Food is good.we ordered Kodi drumsticks and ba...
# Name: Review, dtype: object

# %%
data["Review"] = data["Review"].apply(lambda x : " ".join(x.lower() for x in x.split() ))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data["Review"] = data["Review"].apply(lambda x : " ".join(x.lower() for x in x.split() ))
#
# File ~\Desktop\fyp\good_luck\venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
data["cleaned_review"] = data["Review"].str.lower()

# %%
data["cleaned_review"]
# Out:
# 0       the ambience was good, food was quite good . h...
# 1       ambience is too good for a pleasant evening. s...
# 2       a must try.. great food great ambience. thnx f...
# 3       soumen das and arun was a great guy. only beca...
# 4       food is good.we ordered kodi drumsticks and ba...
#                               ...
# 9995    madhumathi mahajan well to start with nice cou...
# 9996    this place has never disappointed us.. the foo...
# 9997    bad rating is mainly because of "chicken bone ...
# 9998    i personally love and prefer chinese food. had...
# 9999    checked in here to try some delicious chinese ...
# Name: cleaned_review, Length: 10000, dtype: object

# %%
data["cleaned_review"]
# Out:
# 0       the ambience was good, food was quite good . h...
# 1       ambience is too good for a pleasant evening. s...
# 2       a must try.. great food great ambience. thnx f...
# 3       soumen das and arun was a great guy. only beca...
# 4       food is good.we ordered kodi drumsticks and ba...
#                               ...
# 9995    madhumathi mahajan well to start with nice cou...
# 9996    this place has never disappointed us.. the foo...
# 9997    bad rating is mainly because of "chicken bone ...
# 9998    i personally love and prefer chinese food. had...
# 9999    checked in here to try some delicious chinese ...
# Name: cleaned_review, Length: 10000, dtype: object

# %%
import re
import string

# %%
def remove_puntuation(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

data["cleaned_review"] = data["cleaned_review"].apply(remove_puntuation)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 6
#       3         text = text.replace(punctuation, '')
#       4     return text
# ----> 6 data["cleaned_review"] = data["cleaned_review"].apply(remove_puntuation)
#
# File ~\Desktop\fyp\good_luck\venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# ...

# %%
def remove_floats(text):
    if isinstance(text, float):  # Check if the value is a float
        return ""  # Replace float values with an empty string
    return text  # Keep text values as they are

# Apply function to the "Review" column
data["cleaned_review"] = data["cleaned_review"].apply(remove_floats)

# %%
data["cleaned_review"]
# Out:
# 0       the ambience was good, food was quite good . h...
# 1       ambience is too good for a pleasant evening. s...
# 2       a must try.. great food great ambience. thnx f...
# 3       soumen das and arun was a great guy. only beca...
# 4       food is good.we ordered kodi drumsticks and ba...
#                               ...
# 9995    madhumathi mahajan well to start with nice cou...
# 9996    this place has never disappointed us.. the foo...
# 9997    bad rating is mainly because of "chicken bone ...
# 9998    i personally love and prefer chinese food. had...
# 9999    checked in here to try some delicious chinese ...
# Name: cleaned_review, Length: 10000, dtype: object

# %%
def remove_puntuation(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

data["cleaned_review"] = data["cleaned_review"].apply(remove_puntuation)

# %%
data["cleaned_review"]
# Out:
# 0       the ambience was good food was quite good  had...
# 1       ambience is too good for a pleasant evening se...
# 2       a must try great food great ambience thnx for ...
# 3       soumen das and arun was a great guy only becau...
# 4       food is goodwe ordered kodi drumsticks and bas...
#                               ...
# 9995    madhumathi mahajan well to start with nice cou...
# 9996    this place has never disappointed us the food ...
# 9997    bad rating is mainly because of chicken bone f...
# 9998    i personally love and prefer chinese food had ...
# 9999    checked in here to try some delicious chinese ...
# Name: cleaned_review, Length: 10000, dtype: object

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
data["cleaned_review"] = data["cleaned_review"].apply(lambda x : " ".join(re.sub(r'^https?:\/\/.*[\r\n]*', '', x, flags= re.MULTILINE)for x in x.split()))

# %%
data["cleaned_review"]
# Out:
# 0       the ambience was good food was quite good had ...
# 1       ambience is too good for a pleasant evening se...
# 2       a must try great food great ambience thnx for ...
# 3       soumen das and arun was a great guy only becau...
# 4       food is goodwe ordered kodi drumsticks and bas...
#                               ...
# 9995    madhumathi mahajan well to start with nice cou...
# 9996    this place has never disappointed us the food ...
# 9997    bad rating is mainly because of chicken bone f...
# 9998    i personally love and prefer chinese food had ...
# 9999    checked in here to try some delicious chinese ...
# Name: cleaned_review, Length: 10000, dtype: object

# %%
data["cleaned_review"] = data["cleaned_review"].apply(lambda x : " ".join(re.sub(r'^https?:\/\/.*[\r\n]*', '', x, flags= re.MULTILINE)for x in x.split()))

# %%
remove links
# Out:
#   Cell In[36], line 1
#     remove links
#            ^
# SyntaxError: invalid syntax

# %%
data["cleaned_review"]
# Out:
# 0       the ambience was good food was quite good had ...
# 1       ambience is too good for a pleasant evening se...
# 2       a must try great food great ambience thnx for ...
# 3       soumen das and arun was a great guy only becau...
# 4       food is goodwe ordered kodi drumsticks and bas...
#                               ...
# 9995    madhumathi mahajan well to start with nice cou...
# 9996    this place has never disappointed us the food ...
# 9997    bad rating is mainly because of chicken bone f...
# 9998    i personally love and prefer chinese food had ...
# 9999    checked in here to try some delicious chinese ...
# Name: cleaned_review, Length: 10000, dtype: object

# %%
# !pip install nltk

# %%
remove stop words

# %%
import nltk
nltk.download('stopwords', download_dir= '../static/model')
# Out:
# [nltk_data] Downloading package stopwords to ../static/model...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
with open('../static/model/corpora/stopwords/english', 'r') as file:
    sw = file.read().splitlines()

# %%
sw
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
data["cleaned_review"] = data["cleaned_review"].apply(lambda x : " ".join(x for x in x.split() if x not in sw))

# %%
stemmin

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
data["cleaned_review"] = data["cleaned_review"].apply(lambda x: " ".join(ps.stem(x) for x in x.split()))

# %%
data["cleaned_review"]
# Out:
# 0       ambienc good food quit good saturday lunch cos...
# 1       ambienc good pleasant even servic prompt food ...
# 2       must tri great food great ambienc thnx servic ...
# 3       soumen da arun great guy behavior sincereti go...
# 4       food goodw order kodi drumstick basket mutton ...
#                               ...
# 9995    madhumathi mahajan well start nice courteou se...
# 9996    place never disappoint us food courteou staff ...
# 9997    bad rate mainli chicken bone found veg food ac...
# 9998    person love prefer chines food coupl time husb...
# 9999    check tri delici chines food seen nonveg lunch...
# Name: cleaned_review, Length: 10000, dtype: object

# %%
vocabulary

# %%
from collections import Counter
VoCab = Counter()

# %%
for sentence in data["cleaned_review"]:
    VoCab.update(sentence.split())

# %%
len(VoCab)
# Out:
# 15832

# %%
VoCab
# Out:
# Counter({'good': 6998,
#          'food': 6481,
#          'place': 6001,
#          'order': 3599,
#          'servic': 3182,
#          'chicken': 3034,
#          'tast': 2965,
#          'time': 2037,
#          'tri': 2035,
#          'one': 1994,
#          'ambienc': 1992,
#          'great': 1935,
#          'visit': 1872,
#          'like': 1814,
#          'realli': 1659,
#          'serv': 1591,
#          'also': 1577,
#          'nice': 1510,
#          'best': 1432,
#          'restaur': 1428,
#          'love': 1410,
#          'staff': 1375,
#          'biryani': 1368,
#          'experi': 1195,
#          'well': 1130,
#          'veg': 1120,
#          'even': 1103,
#          'would': 1057,
#          'starter': 1053,
#          'dish': 1007,
#          'amaz': 1002,
#          'go': 992,
#          'must': 922,
#          'price': 862,
#          'us': 850,
#          'awesom': 845,
#          'qualiti': 845,
#          'friend': 843,
#          'recommend': 804,
# ...

# %%
tokens = [key for key in VoCab if VoCab[key] > 10]

# %%
tokens
# Out:
# ['ambienc',
#  'good',
#  'food',
#  'quit',
#  'saturday',
#  'lunch',
#  'cost',
#  'effect',
#  'place',
#  'brunch',
#  'one',
#  'also',
#  'chill',
#  'friend',
#  'parent',
#  'waiter',
#  'da',
#  'realli',
#  'courteou',
#  'help',
#  'pleasant',
#  'even',
#  'servic',
#  'prompt',
#  'experi',
#  'kudo',
#  'must',
#  'tri',
#  'great',
#  'pradeep',
#  'person',
#  'recommend',
#  'penn',
#  'alfredo',
#  'pasta',
#  'music',
#  'background',
#  'amaz',
#  'guy',
#  'behavior',
#  'cours',
#  'would',
#  'like',
#  'visit',
#  'order',
#  'kodi',
#  'drumstick',
#  'basket',
#  'mutton',
#  'biryani',
#  'thank',
#  'serv',
#  'well',
#  'enjoy',
#  'ambianc',
#  'best',
#  'papiya',
#  'hostess',
#  'ur',
#  'restaur',
#  'nice',
#  'differ',
#  'tasti',
#  'gud',
#  'worth',
#  'reason',
#  'read',
#  'mani',
#  'review',
#  'final',
#  'come',
#  'crispi',
#  'corn',
#  'tawa',
#  'fish',
#  'ok',
#  'disappoint',
#  'us',
#  'claim',
#  'staff',
#  'polit',
# ...

# %%
def save_vocablary(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w', encoding='utf-8')
    file.write(data)
    file.close()

save_vocablary(tokens, '../static/model/vocabulary.txt')
